# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data=pd.read_csv("C:\\Users\\user\\Desktop\\schneideit\\Sample_for_BI.csv")
data
# Out:
#         ID       Country             Specialization How did you hear about Us  \
# 0        1        Russia    Business Administration             Word Of Mouth
# 1        2         India                        NaN                       NaN
# 2        3         India    Business Administration                       NaN
# 3        4         India      Media and Advertising             Word Of Mouth
# 4        5         India                        NaN                     Other
# ...    ...           ...                        ...                       ...
# 9235  9236  Saudi Arabia     IT Projects Management                       NaN
# 9236  9237         India      Media and Advertising                       NaN
# 9237  9238         India    Business Administration                       NaN
# 9238  9239         India  Human Resource Management             Online Search
# 9239  9240    Bangladesh    Supply Chain Management                       NaN
#
# ...

# %%
data.head()
# Out:
#    ID Country           Specialization How did you hear about Us  \
# 0   1  Russia  Business Administration             Word Of Mouth
# 1   2   India                      NaN                       NaN
# 2   3   India  Business Administration                       NaN
# 3   4   India    Media and Advertising             Word Of Mouth
# 4   5   India                      NaN                     Other
#
#   Current_Occupation What matters most to you in choosing a course  \
# 0         Unemployed                       Better Career Prospects
# 1         Unemployed                       Better Career Prospects
# 2            Student                       Better Career Prospects
# 3         Unemployed                       Better Career Prospects
# 4         Unemployed                       Better Career Prospects
#
#                     Origin          Source Do Not Email Do Not Call  \
# 0                      API      Olark Chat           No          No
# ...

# %%
data.tail()
# Out:
#         ID       Country             Specialization How did you hear about Us  \
# 9235  9236  Saudi Arabia     IT Projects Management                       NaN
# 9236  9237         India      Media and Advertising                       NaN
# 9237  9238         India    Business Administration                       NaN
# 9238  9239         India  Human Resource Management             Online Search
# 9239  9240    Bangladesh    Supply Chain Management                       NaN
#
#      Current_Occupation What matters most to you in choosing a course  \
# 9235         Unemployed                       Better Career Prospects
# 9236         Unemployed                       Better Career Prospects
# 9237         Unemployed                       Better Career Prospects
# 9238                NaN                                           NaN
# 9239         Unemployed                       Better Career Prospects
#
#                        Origin          Source Do Not Email Do Not Call  \
# ...

# %%
data[:60]
# Out:
#     ID Country                     Specialization How did you hear about Us  \
# 0    1  Russia            Business Administration             Word Of Mouth
# 1    2   India                                NaN                       NaN
# 2    3   India            Business Administration                       NaN
# 3    4   India              Media and Advertising             Word Of Mouth
# 4    5   India                                NaN                     Other
# 5    6     NaN                                NaN                       NaN
# 6    7   India            Supply Chain Management             Online Search
# 7    8     NaN                                NaN                       NaN
# 8    9   India             IT Projects Management                       NaN
# 9   10   India                 Finance Management             Word Of Mouth
# 10  11   India                 Travel and Tourism                       NaN
# ...

# %%
data.columns
# Out:
# Index(['ID', 'Country', 'Specialization', 'How did you hear about Us',
#        'Current_Occupation', 'What matters most to you in choosing a course',
#        'Origin', 'Source', 'Do Not Email', 'Do Not Call', 'TotalVisits',
#        'Total Time Spent on Website', 'Page Views Per Visit', 'Last Activity',
#        'Purchased'],
#       dtype='object')

# %%
data.values
# Out:
# array([[1, 'Russia', 'Business Administration', ..., 0.0,
#         'Page Visited on Website', 'No'],
#        [2, 'India', nan, ..., 2.5, 'Email Opened', 'No'],
#        [3, 'India', 'Business Administration', ..., 2.0, 'Email Opened',
#         'Yes'],
#        ...,
#        [9238, 'India', 'Business Administration', ..., 2.0, 'SMS Sent',
#         'No'],
#        [9239, 'India', 'Human Resource Management', ..., 3.0, 'SMS Sent',
#         'Yes'],
#        [9240, 'Bangladesh', 'Supply Chain Management', ..., 3.0,
#         'SMS Sent', 'Yes']], dtype=object)

# %% [markdown]
# ## Looking for NAN values

# %%
data.isnull().sum()
# Out:
# ID                                                  0
# Country                                          2465
# Specialization                                   3379
# How did you hear about Us                        7249
# Current_Occupation                               2690
# What matters most to you in choosing a course    2709
# Origin                                              0
# Source                                             36
# Do Not Email                                        0
# Do Not Call                                         0
# TotalVisits                                       137
# Total Time Spent on Website                         0
# Page Views Per Visit                              137
# Last Activity                                     103
# Purchased                                           0
# dtype: int64

# %% [markdown]
# ## Drop all NAN Values

# %%
data=data.dropna()

# %%
data.isnull().sum()
# Out:
# ID                                               0
# Country                                          0
# Specialization                                   0
# How did you hear about Us                        0
# Current_Occupation                               0
# What matters most to you in choosing a course    0
# Origin                                           0
# Source                                           0
# Do Not Email                                     0
# Do Not Call                                      0
# TotalVisits                                      0
# Total Time Spent on Website                      0
# Page Views Per Visit                             0
# Last Activity                                    0
# Purchased                                        0
# dtype: int64

# %%
data.describe()
# Out:
#                 ID  TotalVisits  Total Time Spent on Website  \
# count  1452.000000  1452.000000                  1452.000000
# mean   4421.378099     4.981405                   727.360882
# std    2601.422938     3.305541                   550.538367
# min       1.000000     0.000000                     0.000000
# 25%    2206.250000     3.000000                   225.000000
# 50%    4334.000000     4.000000                   636.500000
# 75%    6604.750000     6.000000                  1190.000000
# max    9232.000000    43.000000                  2226.000000
#
#        Page Views Per Visit
# count           1452.000000
# mean               3.451694
# std                1.539274
# min                0.000000
# 25%                2.215000
# 50%                3.000000
# 75%                4.000000
# max               14.000000

# %%
data.info
# Out:
# <bound method DataFrame.info of         ID Country                     Specialization  \
# 0        1  Russia            Business Administration
# 3        4   India              Media and Advertising
# 6        7   India            Supply Chain Management
# 18      19   India               Marketing Management
# 20      21   India              Media and Advertising
# ...    ...     ...                                ...
# 9222  9223   India                  Retail Management
# 9224  9225   India              Operations Management
# 9227  9228   India            Supply Chain Management
# 9230  9231   India          Human Resource Management
# 9231  9232   India  Banking, Investment And Insurance
#
#      How did you hear about Us Current_Occupation  \
# 0                Word Of Mouth         Unemployed
# 3                Word Of Mouth         Unemployed
# 6                Online Search         Unemployed
# 18            Multiple Sources         Unemployed
# ...

# %% [markdown]
# ## Country Unique

# %%
data['Country'].unique()
# Out:
# array(['Russia', 'India', 'Australia', 'United Arab Emirates', 'France',
#        'Hong Kong', 'Singapore', 'United Kingdom', 'United States',
#        'Oman', 'Bahrain', 'Saudi Arabia', 'Germany'], dtype=object)

# %% [markdown]
# ## Country Value Counts

# %%
data['Country'].value_counts()
# Out:
# India                   1430
# Australia                  4
# United Arab Emirates       3
# United Kingdom             3
# United States              3
# Hong Kong                  2
# Russia                     1
# France                     1
# Singapore                  1
# Oman                       1
# Bahrain                    1
# Saudi Arabia               1
# Germany                    1
# Name: Country, dtype: int64

# %% [markdown]
# ## Current Occupation Unique

# %%
data['Current_Occupation'].unique()
# Out:
# array(['Unemployed', 'Working Professional', 'Student', 'Other',
#        'Housewife', 'Businessman'], dtype=object)

# %% [markdown]
# ## Current Occupation Value Counts

# %%
data['Current_Occupation'].value_counts()
# Out:
# Unemployed              1273
# Working Professional     146
# Student                   28
# Other                      2
# Housewife                  2
# Businessman                1
# Name: Current_Occupation, dtype: int64

# %% [markdown]
# ## Specialization Unique

# %%
data['Specialization'].unique()
# Out:
# array(['Business Administration', 'Media and Advertising',
#        'Supply Chain Management', 'Marketing Management',
#        'Banking, Investment And Insurance', 'Finance Management',
#        'Travel and Tourism', 'Operations Management', 'Retail Management',
#        'IT Projects Management', 'International Business',
#        'Hospitality Management', 'Healthcare Management',
#        'Human Resource Management', 'E-COMMERCE',
#        'Rural and Agribusiness', 'E-Business', 'Services Excellence'],
#       dtype=object)

# %% [markdown]
# ## Total Visits Unique

# %%
data['TotalVisits'].unique()
# Out:
# array([ 0.,  1.,  2.,  6.,  4.,  3.,  5.,  7., 13.,  8., 10.,  9., 11.,
#        15., 43., 18., 12., 14., 23., 21., 20., 16., 29., 24., 22., 17.,
#        27., 19.])

# %% [markdown]
# ## What matters most to you in choosing a course Unique

# %%
data['What matters most to you in choosing a course'].unique()
# Out:
# array(['Better Career Prospects'], dtype=object)

# %% [markdown]
# ## Total Time Spent on Website Unique

# %%
data['Total Time Spent on Website'].unique()
# Out:
# array([   0,  305, 1640, 1688,  233, 1013,  771, 1068, 1315, 1622,  563,
#          25,   38,  287,  160,  436,  213,  157,  219,  595,  520, 1136,
#         511, 1190,  652, 1091,  386, 1603,  232,  919,  194,   65, 1953,
#        1587, 1362,   74,  732,  294,  228,   43,  174, 1189,   73,  263,
#          67,  199,  556, 1088,   58,    3,  901, 1939, 1226,  214,  274,
#        1354, 1102, 1128,  109,   98,  339,  235,  281, 1468,  107,  663,
#        1357, 1412,  746,  267,    2,  181,  825,  110,  262,  362, 1132,
#         347, 1712,  598,  332,  628, 1092,    7, 1368,   94, 1482,  472,
#         312,  210,  363, 1328, 1191, 1595,   66,   92,  818,  346,  583,
#         285,  444, 1160,   59,  225, 1120, 1058, 1335, 1342,  605, 1452,
#         179,  376,  638,  938,  120,  168, 1051,  854, 1966,  164, 1169,
#        1071,  781,   60,  266, 1117,  137, 1224,  911,  297, 1471,  610,
#        1704,   28, 1521,  950,  542,  125, 1134, 1346, 1995, 1758,  152,
# ...

# %% [markdown]
# ## Total Time Spent on Website Value Counts

# %%
data['Total Time Spent on Website'].value_counts()
# Out:
# 1049    6
# 346     5
# 287     5
# 952     5
# 45      5
#        ..
# 297     1
# 1904    1
# 911     1
# 634     1
# 455     1
# Name: Total Time Spent on Website, Length: 939, dtype: int64

# %% [markdown]
# ## What matters most to you in choosing a course Unique

# %%
data['What matters most to you in choosing a course'].unique()
# Out:
# array(['Better Career Prospects'], dtype=object)

# %% [markdown]
# ## What matters most to you in choosing a course Unique Counts

# %%
data['What matters most to you in choosing a course'].value_counts()
# Out:
# Better Career Prospects    1452
# Name: What matters most to you in choosing a course, dtype: int64

# %% [markdown]
# ## Visualization of Countries

# %%
plt.figure(figsize=(15,15))
plt.xticks(rotation=90)
sns.countplot(y='Country',data=data,order=data['Country'].value_counts().index)
plt.title("Country")
plt.show()

# %% [markdown]
# ## Visualization of Current Occupation

# %%
plt.figure(figsize=(10,10))
plt.xticks(rotation=90)
sns.countplot(y='Current_Occupation',data=data,order=data['Current_Occupation'].value_counts().index)
plt.title("Current occupation")
plt.show()

# %% [markdown]
# ## Visualization of What matters most to you in choosing a course

# %%
plt.figure(figsize=(5,5))
plt.xticks(rotation=90)
sns.countplot(y='What matters most to you in choosing a course',data=data,order=data['What matters most to you in choosing a course'].value_counts().index)
plt.title('What matters most to you in choosing a course')
plt.show()

# %%
data['Country'].value_counts()
# Out:
# India                   1430
# Australia                  4
# United Arab Emirates       3
# United Kingdom             3
# United States              3
# Hong Kong                  2
# Russia                     1
# France                     1
# Singapore                  1
# Oman                       1
# Bahrain                    1
# Saudi Arabia               1
# Germany                    1
# Name: Country, dtype: int64

# %%
data['Current_Occupation'].value_counts()
# Out:
# Unemployed              1273
# Working Professional     146
# Student                   28
# Other                      2
# Housewife                  2
# Businessman                1
# Name: Current_Occupation, dtype: int64

# %% [markdown]
# ## How did you hear about us unique

# %%
data['How did you hear about Us'].unique()
# Out:
# array(['Word Of Mouth', 'Online Search', 'Multiple Sources',
#        'Advertisements', 'Student of SomeSchool', 'Other', 'Email',
#        'Social Media', 'SMS'], dtype=object)

# %% [markdown]
# ## How did you hear about us Value Counts

# %%
data['How did you hear about Us'].value_counts()
# Out:
# Online Search            591
# Word Of Mouth            248
# Student of SomeSchool    234
# Other                    137
# Multiple Sources         109
# Social Media              52
# Advertisements            48
# Email                     21
# SMS                       12
# Name: How did you hear about Us, dtype: int64

# %% [markdown]
# ## Visualization of How did you hear about us

# %%
plt.figure(figsize=(10,10))
plt.xticks(rotation=90)
sns.countplot(y='How did you hear about Us',data=data,order=data['How did you hear about Us'].value_counts().index)
plt.title('How did you hear about Us')
plt.show()

# %% [markdown]
# ## Specialization Value Counts

# %%
data['Specialization'].value_counts()
# Out:
# Finance Management                   280
# Human Resource Management            223
# Marketing Management                 211
# Operations Management                128
# Business Administration              113
# Banking, Investment And Insurance    105
# IT Projects Management                89
# Supply Chain Management               66
# Media and Advertising                 51
# International Business                41
# Retail Management                     32
# Hospitality Management                25
# Travel and Tourism                    23
# Healthcare Management                 22
# E-COMMERCE                            16
# E-Business                            14
# Rural and Agribusiness                10
# Services Excellence                    3
# Name: Specialization, dtype: int64

# %% [markdown]
# ## Visualization of Specialization

# %%
plt.figure(figsize=(10,10))
plt.xticks(rotation=90)
sns.countplot(y='Specialization',data=data,order=data['Specialization'].value_counts().index)
plt.title('Specialization')
plt.show()

# %% [markdown]
# ## Purchased Value Counts

# %%
data['Purchased'].value_counts()
# Out:
# Yes    748
# No     704
# Name: Purchased, dtype: int64

# %% [markdown]
# ## Visualization of Purchased

# %%
plt.figure(figsize=(10,10))
plt.xticks(rotation=90)
sns.countplot(y='Purchased',data=data,order=data['Purchased'].value_counts().index)
plt.title('Purchased')
plt.show()

# %% [markdown]
# ## Orgin Value Count

# %%
data['Origin'].value_counts()
# Out:
# Landing Page Submission    1345
# API                         100
# Lead Add Form                 7
# Name: Origin, dtype: int64

# %% [markdown]
# ## Visualization of Origin

# %%
plt.figure(figsize=(10,10))
plt.xticks(rotation=90)
sns.countplot(y='Origin',data=data,order=data['Origin'].value_counts().index)
plt.title('Origin')
plt.show()

# %% [markdown]
# ## Source Value Counts

# %%
data['Source'].value_counts()
# Out:
# Google               1164
# Direct Traffic        198
# Organic Search         47
# Olark Chat             27
# Referral Sites          6
# Reference               4
# Welingak Website        2
# Pay per Click Ads       1
# Click2call              1
# bing                    1
# testone                 1
# Name: Source, dtype: int64

# %% [markdown]
# ## Visualization of Source

# %%
plt.figure(figsize=(10,10))
plt.xticks(rotation=90)
sns.countplot(y='Source',data=data,order=data['Source'].value_counts().index)
plt.title('Source')
plt.show()

# %% [markdown]
# ## Do Not Email Value Counts

# %%
data['Do Not Email'].value_counts()
# Out:
# No     1395
# Yes      57
# Name: Do Not Email, dtype: int64

# %% [markdown]
# ## Visualization of Do Not Email

# %%
plt.figure(figsize=(10,10))
plt.xticks(rotation=90)
sns.countplot(y='Do Not Email',data=data,order=data['Do Not Email'].value_counts().index)
plt.title('Do Not Email')
plt.show()

# %% [markdown]
# ## Do Not Call Value Counts

# %%
data['Do Not Call'].value_counts()
# Out:
# No     1451
# Yes       1
# Name: Do Not Call, dtype: int64

# %% [markdown]
# ## Visualization of Do Not Call

# %%
plt.figure(figsize=(10,10))
plt.xticks(rotation=90)
sns.countplot(y='Do Not Call',data=data,order=data['Do Not Call'].value_counts().index)
plt.title('Do Not Call')
plt.show()

# %% [markdown]
# ## Total Visits Value Counts

# %%
data['TotalVisits'].value_counts()
# Out:
# 4.0     366
# 3.0     256
# 5.0     240
# 2.0     174
# 6.0     124
# 7.0      77
# 8.0      52
# 9.0      37
# 1.0      25
# 10.0     24
# 11.0     17
# 13.0     11
# 14.0      9
# 12.0      9
# 15.0      5
# 17.0      3
# 23.0      3
# 16.0      3
# 18.0      3
# 27.0      2
# 24.0      2
# 0.0       2
# 19.0      2
# 20.0      2
# 29.0      1
# 22.0      1
# 21.0      1
# 43.0      1
# Name: TotalVisits, dtype: int64

# %% [markdown]
# ## Visualization of Total Visits

# %%
plt.figure(figsize=(10,10))
plt.xticks(rotation=90)
sns.countplot(y='TotalVisits',data=data,order=data['TotalVisits'].value_counts().index)
plt.title('TotalVisits')
plt.show()

# %% [markdown]
# ## Extract Current Occupation Data

# %%
data=pd.concat([data,pd.get_dummies(data['Current_Occupation'])], axis=1)
data
# Out:
#         ID Country                     Specialization  \
# 0        1  Russia            Business Administration
# 3        4   India              Media and Advertising
# 6        7   India            Supply Chain Management
# 18      19   India               Marketing Management
# 20      21   India              Media and Advertising
# ...    ...     ...                                ...
# 9222  9223   India                  Retail Management
# 9224  9225   India              Operations Management
# 9227  9228   India            Supply Chain Management
# 9230  9231   India          Human Resource Management
# 9231  9232   India  Banking, Investment And Insurance
#
#      How did you hear about Us Current_Occupation  \
# 0                Word Of Mouth         Unemployed
# 3                Word Of Mouth         Unemployed
# 6                Online Search         Unemployed
# 18            Multiple Sources         Unemployed
# 20               Online Search         Unemployed
# ...

# %% [markdown]
# ## Extract Country Data

# %%
data=pd.concat([data,pd.get_dummies(data['Country'])], axis=1)
data
# Out:
#         ID Country                     Specialization  \
# 0        1  Russia            Business Administration
# 3        4   India              Media and Advertising
# 6        7   India            Supply Chain Management
# 18      19   India               Marketing Management
# 20      21   India              Media and Advertising
# ...    ...     ...                                ...
# 9222  9223   India                  Retail Management
# 9224  9225   India              Operations Management
# 9227  9228   India            Supply Chain Management
# 9230  9231   India          Human Resource Management
# 9231  9232   India  Banking, Investment And Insurance
#
#      How did you hear about Us Current_Occupation  \
# 0                Word Of Mouth         Unemployed
# 3                Word Of Mouth         Unemployed
# 6                Online Search         Unemployed
# 18            Multiple Sources         Unemployed
# 20               Online Search         Unemployed
# ...

# %%
data.columns
# Out:
# Index(['ID', 'Country', 'Specialization', 'How did you hear about Us',
#        'Current_Occupation', 'What matters most to you in choosing a course',
#        'Origin', 'Source', 'Do Not Email', 'Do Not Call', 'TotalVisits',
#        'Total Time Spent on Website', 'Page Views Per Visit', 'Last Activity',
#        'Purchased', 'Businessman', 'Housewife', 'Other', 'Student',
#        'Unemployed', 'Working Professional', 'Australia', 'Bahrain', 'France',
#        'Germany', 'Hong Kong', 'India', 'Oman', 'Russia', 'Saudi Arabia',
#        'Singapore', 'United Arab Emirates', 'United Kingdom', 'United States'],
#       dtype='object')

# %% [markdown]
# ## Visualize the Distribution of Purchased

# %%
count_purchased=data['Purchased'].value_counts()
labels_purchased=data['Purchased'].unique()

# %%
plt.figure(figsize=(20,20))
from matplotlib.gridspec import GridSpec
grid=GridSpec(2,2)
cmap=plt.get_cmap('Accent')
colors=[cmap(i) for i in np.linspace(0,1,3)]
plt.subplot(grid[0,1],aspect=1,title='Purchased Distribution')
pie=plt.pie(count_purchased,labels=labels_purchased,autopct='%1.1f%%',colors=colors)

# %% [markdown]
# ## Last Activity Value Counts

# %%
data['Last Activity'].value_counts()
# Out:
# Email Opened                    611
# SMS Sent                        489
# Page Visited on Website         114
# Form Submitted on Website        55
# Converted to Lead                48
# Email Link Clicked               33
# Olark Chat Conversation          33
# Unreachable                      27
# Email Bounced                    21
# Unsubscribed                     10
# Had a Phone Conversation          7
# Email Received                    2
# Visited Booth in Tradeshow        1
# View in browser link Clicked      1
# Name: Last Activity, dtype: int64

# %% [markdown]
# ## Visualization of Last Activity

# %%
plt.figure(figsize=(10,10))
plt.xticks(rotation=90)
sns.countplot(y='Last Activity',data=data,order=data['Last Activity'].value_counts().index)
plt.title('Last Activity')
plt.show()

# %% [markdown]
# ## Visualize the Distribution of Last Activity

# %%
count_last_activity=data['Last Activity'].value_counts()
labels_last_activity=data[ 'Last Activity'].unique()

# %%
plt.figure(figsize=(20,20))
from matplotlib.gridspec import GridSpec
grid=GridSpec(2,2)
cmap=plt.get_cmap('Accent')
colors=[cmap(i) for i in np.linspace(0,1,3)]
plt.subplot(grid[0,1],aspect=1,title='Last Activity Distribution')
pie=plt.pie(count_last_activity,labels=labels_last_activity,autopct='%1.1f%%',colors=colors)

# %% [markdown]
# ## Visualize the Distribution of Specialization

# %%
count_specialization=data['Specialization'].value_counts()
labels_specialization=data[ 'Specialization'].unique()

# %%
plt.figure(figsize=(20,20))
from matplotlib.gridspec import GridSpec
grid=GridSpec(2,2)
cmap=plt.get_cmap('Accent')
colors=[cmap(i) for i in np.linspace(0,1,3)]
plt.subplot(grid[0,1],aspect=1,title='Specialization Distribution')
pie=plt.pie(count_specialization,labels=labels_specialization,autopct='%1.1f%%',colors=colors)

# %%
data['Current_Occupation'].unique()
# Out:
# array(['Unemployed', 'Working Professional', 'Student', 'Other',
#        'Housewife', 'Businessman'], dtype=object)

# %% [markdown]
# ## Visualize the Distribution of Current Occupation

# %%
count_occupation=data['Current_Occupation'].value_counts()
labels_occupation=data[ 'Current_Occupation'].unique()

# %%
plt.figure(figsize=(20,20))
from matplotlib.gridspec import GridSpec
grid=GridSpec(2,2)
cmap=plt.get_cmap('Accent')
colors=[cmap(i) for i in np.linspace(0,1,3)]
plt.subplot(grid[0,1],aspect=1,title='Occupation')
pie=plt.pie(count_occupation,labels=labels_occupation,autopct='%1.1f%%',colors=colors)

# %% [markdown]
# ## Visualize the Distribution of Orgin

# %%
count_orgin=data['Origin' ].value_counts()
labels_orgin=data['Origin'].unique()

# %%
plt.figure(figsize=(20,20))
from matplotlib.gridspec import GridSpec
grid=GridSpec(2,2)
cmap=plt.get_cmap('Accent')
colors=[cmap(i) for i in np.linspace(0,1,3)]
plt.subplot(grid[0,1],aspect=1,title='Orgin Distribution')
pie=plt.pie(count_orgin,labels=labels_orgin,autopct='%1.1f%%',colors=colors)

# %%
data=pd.concat([data,pd.get_dummies(data['Purchased'])], axis=1)
data
# Out:
#         ID Country                     Specialization  \
# 0        1  Russia            Business Administration
# 3        4   India              Media and Advertising
# 6        7   India            Supply Chain Management
# 18      19   India               Marketing Management
# 20      21   India              Media and Advertising
# ...    ...     ...                                ...
# 9222  9223   India                  Retail Management
# 9224  9225   India              Operations Management
# 9227  9228   India            Supply Chain Management
# 9230  9231   India          Human Resource Management
# 9231  9232   India  Banking, Investment And Insurance
#
#      How did you hear about Us Current_Occupation  \
# 0                Word Of Mouth         Unemployed
# 3                Word Of Mouth         Unemployed
# 6                Online Search         Unemployed
# 18            Multiple Sources         Unemployed
# 20               Online Search         Unemployed
# ...

# %%
data.columns
# Out:
# Index(['ID', 'Country', 'Specialization', 'How did you hear about Us',
#        'Current_Occupation', 'What matters most to you in choosing a course',
#        'Origin', 'Source', 'Do Not Email', 'Do Not Call', 'TotalVisits',
#        'Total Time Spent on Website', 'Page Views Per Visit', 'Last Activity',
#        'Purchased', 'Businessman', 'Housewife', 'Other', 'Student',
#        'Unemployed', 'Working Professional', 'Australia', 'Bahrain', 'France',
#        'Germany', 'Hong Kong', 'India', 'Oman', 'Russia', 'Saudi Arabia',
#        'Singapore', 'United Arab Emirates', 'United Kingdom', 'United States',
#        'No', 'Yes'],
#       dtype='object')

# %%
data['Purchased']
# Out:
# 0        No
# 3        No
# 6       Yes
# 18      Yes
# 20       No
#        ...
# 9222     No
# 9224     No
# 9227    Yes
# 9230     No
# 9231    Yes
# Name: Purchased, Length: 1452, dtype: object

# %%
data['Yes']
# Out:
# 0       0
# 3       0
# 6       1
# 18      1
# 20      0
#        ..
# 9222    0
# 9224    0
# 9227    1
# 9230    0
# 9231    1
# Name: Yes, Length: 1452, dtype: uint8

# %%
data['No']
# Out:
# 0       1
# 3       1
# 6       0
# 18      0
# 20      1
#        ..
# 9222    1
# 9224    1
# 9227    0
# 9230    1
# 9231    0
# Name: No, Length: 1452, dtype: uint8

# %% [markdown]
# ## 1: Total number of working professionals who has purchased the product from India ?

# %%
data_india_products=data.groupby(by=['Country','Purchased'],as_index=False).aggregate({'Working Professional':"sum"})
data_india_products
# Out:
#                  Country Purchased  Working Professional
# 0              Australia        No                     0
# 1              Australia       Yes                     0
# 2                Bahrain        No                     0
# 3                 France       Yes                     0
# 4                Germany        No                     0
# 5              Hong Kong        No                     0
# 6              Hong Kong       Yes                     0
# 7                  India        No                    13
# 8                  India       Yes                   131
# 9                   Oman        No                     0
# 10                Russia        No                     0
# 11          Saudi Arabia        No                     0
# 12             Singapore        No                     0
# 13  United Arab Emirates        No                     0
# 14  United Arab Emirates       Yes                     2
# ...

# %%
display(data_india_products.iloc[8])
# Out:
# Country                 India
# Purchased                 Yes
# Working Professional      131
# Name: 8, dtype: object

# %% [markdown]
# ## Ans:  131 Working Professionals purchased the Products from India

# %%
data1=pd.concat([data,pd.get_dummies(data['How did you hear about Us'])], axis=1)
data1
# Out:
#         ID Country                     Specialization  \
# 0        1  Russia            Business Administration
# 3        4   India              Media and Advertising
# 6        7   India            Supply Chain Management
# 18      19   India               Marketing Management
# 20      21   India              Media and Advertising
# ...    ...     ...                                ...
# 9222  9223   India                  Retail Management
# 9224  9225   India              Operations Management
# 9227  9228   India            Supply Chain Management
# 9230  9231   India          Human Resource Management
# 9231  9232   India  Banking, Investment And Insurance
#
#      How did you hear about Us Current_Occupation  \
# 0                Word Of Mouth         Unemployed
# 3                Word Of Mouth         Unemployed
# 6                Online Search         Unemployed
# 18            Multiple Sources         Unemployed
# 20               Online Search         Unemployed
# ...

# %%
data1.columns
# Out:
# Index(['ID', 'Country', 'Specialization', 'How did you hear about Us',
#        'Current_Occupation', 'What matters most to you in choosing a course',
#        'Origin', 'Source', 'Do Not Email', 'Do Not Call', 'TotalVisits',
#        'Total Time Spent on Website', 'Page Views Per Visit', 'Last Activity',
#        'Purchased', 'Businessman', 'Housewife', 'Other', 'Student',
#        'Unemployed', 'Working Professional', 'Australia', 'Bahrain', 'France',
#        'Germany', 'Hong Kong', 'India', 'Oman', 'Russia', 'Saudi Arabia',
#        'Singapore', 'United Arab Emirates', 'United Kingdom', 'United States',
#        'No', 'Yes', 'Advertisements', 'Email', 'Multiple Sources',
#        'Online Search', 'Other', 'SMS', 'Social Media',
#        'Student of SomeSchool', 'Word Of Mouth'],
#       dtype='object')

# %% [markdown]
# ## 2 : Total number of students who purchased Finance Management course who came from online search ?

# %%
data_finance=data1.groupby(by=['Specialization','Online Search'],as_index=False).aggregate({'Student':"sum"})
data_finance
# Out:
#                        Specialization  Online Search  Student
# 0   Banking, Investment And Insurance              0        2
# 1   Banking, Investment And Insurance              1        1
# 2             Business Administration              0        1
# 3             Business Administration              1        1
# 4                          E-Business              0        0
# 5                          E-Business              1        0
# 6                          E-COMMERCE              0        0
# 7                          E-COMMERCE              1        0
# 8                  Finance Management              0        5
# 9                  Finance Management              1        4
# 10              Healthcare Management              0        2
# 11              Healthcare Management              1        0
# 12             Hospitality Management              0        0
# 13             Hospitality Management              1        0
# ...

# %%
display(data_finance.iloc[9])
# Out:
# Specialization    Finance Management
# Online Search                      1
# Student                            4
# Name: 9, dtype: object

# %% [markdown]
# ## Ans:  4 students are purchased Finance Management course from online search

# %% [markdown]
# ## Visualize the Distribution of Do Not Email

# %%
count_not_email=data['Do Not Email' ].value_counts()
labels_not_email=data['Do Not Email'].unique()

# %%
plt.figure(figsize=(10,10))
from matplotlib.gridspec import GridSpec
grid=GridSpec(2,2)
cmap=plt.get_cmap('Accent')
colors=[cmap(i) for i in np.linspace(0,1,3)]
plt.subplot(grid[0,1],aspect=1,title='Do not Email Distribution')
pie=plt.pie(count_not_email,labels=labels_not_email,autopct='%1.1f%%',colors=colors)

# %% [markdown]
# ## Visualize the Distribution of What matters most to you in choosing a course

# %%
count_matters=data['What matters most to you in choosing a course' ].value_counts()
labels_matters=data['What matters most to you in choosing a course'].unique()

# %%
plt.figure(figsize=(10,10))
from matplotlib.gridspec import GridSpec
grid=GridSpec(2,2)
cmap=plt.get_cmap('Accent')
colors=[cmap(i) for i in np.linspace(0,1,3)]
plt.subplot(grid[0,1],aspect=1,title='What matters most to you in choosing a course Distribution')
pie=plt.pie(count_matters,labels=labels_matters,autopct='%1.1f%%',colors=colors)

# %% [markdown]
# ## India Occupation Status

# %%
plt.figure(figsize=(8,8))
sns.barplot(data['Unemployed'],data['India'])
plt.xlabel('Unemployment')
plt.ylabel('India')
plt.title("India vs Unemployment (Bar Plot)")
plt.grid()
plt.legend()
plt.show()


plt.figure(figsize=(8,8))
sns.barplot(data['Student'],data['India'])
plt.xlabel('Student')
plt.ylabel('India')
plt.title("India vs'Student'(Bar Plot)")
plt.grid()
plt.legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# -  India have 90%(0.9) Unemployed(1)
# - Students 100% (1)

# %%
plt.figure(figsize=(8,8))
sns.barplot(data['Housewife'],data['India'])
plt.xlabel('Housewife')
plt.ylabel('India')
plt.title("India vs'Housewife'(Bar Plot)")
plt.grid()
plt.legend()
plt.show()
           
plt.figure(figsize=(8,8))
sns.barplot(data['Businessman'],data['India'])
plt.xlabel('Businessman')
plt.ylabel('India')
plt.title("India vs'Businessman'(Bar Plot)")
plt.grid()
plt.legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# - India have 100% House Wife(1)
# - India Have 100% Bussinessman(1)

# %%
plt.figure(figsize=(8,8))
sns.barplot(data['Working Professional'],data['India'])
plt.xlabel('Working Professional')
plt.ylabel('India')
plt.title("India vs'Working Professional'(Bar Plot)")
plt.grid()
plt.legend()
plt.show()  

plt.figure(figsize=(8,8))
sns.barplot(data['Other'],data['India'])
plt.xlabel('Other')
plt.ylabel('India')
plt.title("India vs'Other'(Bar Plot)")
plt.grid()
plt.legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# - India have 90% Working Professional(1)
# - India have 100% Other(1)

# %%
data.columns
# Out:
# Index(['ID', 'Country', 'Specialization', 'How did you hear about Us',
#        'Current_Occupation', 'What matters most to you in choosing a course',
#        'Origin', 'Source', 'Do Not Email', 'Do Not Call', 'TotalVisits',
#        'Total Time Spent on Website', 'Page Views Per Visit', 'Last Activity',
#        'Purchased', 'Businessman', 'Housewife', 'Other', 'Student',
#        'Unemployed', 'Working Professional', 'Australia', 'Bahrain', 'France',
#        'Germany', 'Hong Kong', 'India', 'Oman', 'Russia', 'Saudi Arabia',
#        'Singapore', 'United Arab Emirates', 'United Kingdom', 'United States',
#        'No', 'Yes'],
#       dtype='object')

# %% [markdown]
# ## Australia Occupation Status

# %%
plt.figure(figsize=(8,8))
sns.barplot(data['Unemployed'],data['Australia'])
plt.xlabel('Unemployed')
plt.ylabel('Australia')
plt.title("Australia vs Unemployment (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(8,8))
sns.barplot(data['Working Professional'],data['Australia'])
plt.xlabel('Working professionals')
plt.ylabel('Australia')
plt.title("Australia vs 'Working Professional' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# - Australia have 3.2% Unemployment(0.0032)(1)
# - Australia have 0 Working Professionals(1), no 1 in data

# %%
plt.figure(figsize=(8,8))
sns.barplot(data['Student'],data['Australia'])
plt.xlabel('Student')
plt.ylabel('Australia')
plt.title("Australia vs 'Student' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(8,8))
sns.barplot(data['Businessman'],data['Australia'])
plt.xlabel('Businessman')
plt.ylabel('Australia')
plt.title("Australia vs 'Businessman' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# - Australia have 0 Student(1), no 1 is in data
# - Australia have 0 Businessman(1), no 1 is in data

# %%
plt.figure(figsize=(8,8))
sns.barplot(data['Housewife'],data['Australia'])
plt.xlabel('Housewife')
plt.ylabel('Australia')
plt.title("Australia vs 'Housewife' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(8,8))
sns.barplot(data['Other'],data['Australia'])
plt.xlabel('Other')
plt.ylabel('Australia')
plt.title("Australia vs 'Other' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# - Australia have 0% House Wife, No 1 in data
# - Australia have 0% Other, No 1 in data

# %%
data.columns
# Out:
# Index(['ID', 'Country', 'Specialization', 'How did you hear about Us',
#        'Current_Occupation', 'What matters most to you in choosing a course',
#        'Origin', 'Source', 'Do Not Email', 'Do Not Call', 'TotalVisits',
#        'Total Time Spent on Website', 'Page Views Per Visit', 'Last Activity',
#        'Purchased', 'Businessman', 'Housewife', 'Other', 'Student',
#        'Unemployed', 'Working Professional', 'Australia', 'Bahrain', 'France',
#        'Germany', 'Hong Kong', 'India', 'Oman', 'Russia', 'Saudi Arabia',
#        'Singapore', 'United Arab Emirates', 'United Kingdom', 'United States',
#        'No', 'Yes'],
#       dtype='object')

# %% [markdown]
# ## Bahrain Occupation Status

# %%
plt.figure(figsize=(5,5))
sns.barplot(data['Unemployed'],data['Bahrain'])
plt.xlabel('Unemployed')
plt.ylabel('Bahrain')
plt.title("Bahrain vs Unemployment (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Working Professional'],data['Bahrain'])
plt.xlabel('Working professionals')
plt.ylabel('Bahrain')
plt.title("'Bahrain' vs 'Working Professional' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(8,8))
sns.barplot(data['Student'],data['Bahrain'])
plt.xlabel('Student')
plt.ylabel('Bahrain')
plt.title("'Bahrain' vs 'Student' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Businessman'],data['Bahrain'])
plt.xlabel('Businessman')
plt.ylabel('Bahrain')
plt.title("'Bahrain' vs 'Businessman' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(5,5))
sns.barplot(data['Housewife'],data['Bahrain'])
plt.xlabel('Housewife')
plt.ylabel('Bahrain')
plt.title("'Bahrain' vs 'Housewife' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Other'],data['Bahrain'])
plt.xlabel('Other')
plt.ylabel('Bahrain')
plt.title("'Bahrain' vs 'Other' (Bar Plot)")
plt.legend()
plt.grid()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...

# %% [markdown]
# - Bahrain have 0.07% Unemployment(around 0.0007)(1)
# - Bahrain have 0% Working Professionals, Because in data didn't show 1
# - Bahrain have 0% Students, Because in data didn't show 1
# - Bahrain have 0% Businessman, Because in data didn't show 1

# %% [markdown]
# ## France Occupation Status

# %%
plt.figure(figsize=(5,5))
sns.barplot(data['Unemployed'],data[ 'France'])
plt.xlabel('Unemployed')
plt.ylabel('France')
plt.title(" 'France' vs Unemployment (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Working Professional'],data[ 'France'])
plt.xlabel('Working professionals')
plt.ylabel( 'France')
plt.title(" 'France'vs 'Working Professional' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(8,8))
sns.barplot(data['Student'],data[ 'France'])
plt.xlabel('Student')
plt.ylabel( 'France')
plt.title(" 'France' vs 'Student' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Businessman'],data[ 'France'])
plt.xlabel('Businessman')
plt.ylabel('France')
plt.title(" 'France' vs 'Businessman' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(5,5))
sns.barplot(data['Housewife'],data[ 'France'])
plt.xlabel('Housewife')
plt.ylabel( 'France')
plt.title(" 'France' vs 'Housewife' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Other'],data[ 'France'])
plt.xlabel('Other')
plt.ylabel( 'France')
plt.title(" 'France'vs 'Other' (Bar Plot)")
plt.legend()
plt.grid()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...

# %% [markdown]
# - France have 0.07% Unemployment( around 0.0007)(1)
# - France have 0% Working professionals, Because in data didn't show 1
# - France have 0% Student, Because in data didn't show 1
# - France have 0% Businessman, Because in data didn't show 1

# %% [markdown]
# ## Germany Occupation Status

# %%
plt.figure(figsize=(5,5))
sns.barplot(data['Unemployed'],data[  'Germany'])
plt.xlabel('Unemployed')
plt.ylabel( 'Germany')
plt.title("  'Germany' vs Unemployment (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Working Professional'],data[  'Germany'])
plt.xlabel('Working professionals')
plt.ylabel(  'Germany')
plt.title("  'Germany' vs 'Working Professional' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(8,8))
sns.barplot(data['Student'],data[  'Germany'])
plt.xlabel('Student')
plt.ylabel(  'Germany')
plt.title("  'Germany' vs 'Student' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Businessman'],data[  'Germany'])
plt.xlabel('Businessman')
plt.ylabel( 'Germany')
plt.title("  'Germany' vs 'Businessman' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(5,5))
sns.barplot(data['Housewife'],data[  'Germany'])
plt.xlabel('Housewife')
plt.ylabel(  'Germany')
plt.title("  'Germany' vs 'Housewife' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Other'],data[  'Germany'])
plt.xlabel('Other')
plt.ylabel(  'Germany')
plt.title("  'Germany'vs 'Other' (Bar Plot)")
plt.legend()
plt.grid()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...

# %% [markdown]
# - Germany have 0.07% Unemployed( around 0.0007)(1)
# - Germany have 0% Working Professionals, Because in data didn't show 1
# - Germany have 0% Student, Because in data didn't show 1
# - Germany have 0% Businessman, Because in data didn't show 1
# - Germany have 0% House Wife, Because in data didn't show 1
# - Germany have 0% Other, Because in data didn't show 1

# %% [markdown]
# ## Hong Kong Occupation Status

# %%
plt.figure(figsize=(5,5))
sns.barplot(data['Unemployed'],data[   'Hong Kong'])
plt.xlabel('Unemployed')
plt.ylabel(  'Hong Kong')
plt.title(" 'Hong Kong' vs Unemployment (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Working Professional'],data['Hong Kong'])
plt.xlabel('Working professionals')
plt.ylabel(   'Hong Kong')
plt.title("   'Hong Kong' vs 'Working Professional' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(8,8))
sns.barplot(data['Student'],data[  'Hong Kong'])
plt.xlabel('Student')
plt.ylabel(   'Hong Kong')
plt.title("  'Hong Kong' vs 'Student' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Businessman'],data[ 'Hong Kong'])
plt.xlabel('Businessman')
plt.ylabel(  'Hong Kong')
plt.title("   'Hong Kong' vs 'Businessman' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(5,5))
sns.barplot(data['Housewife'],data[   'Hong Kong'])
plt.xlabel('Housewife')
plt.ylabel(  'Hong Kong')
plt.title("   'Hong Kong' vs 'Housewife' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Other'],data[ 'Hong Kong'])
plt.xlabel('Other')
plt.ylabel('Hong Kong')
plt.title("'Hong Kong' vs 'Other' (Bar Plot)")
plt.legend()
plt.grid()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...

# %% [markdown]
# - Hong Kong have 0.16% Unemployed(around 0.0016)(1)
# - Hong Kong have 0% Working Professionals, Because in data didn't show 1
# - Hong Kong have 0% Student,Because in data didn't show 1
# - Honk Kong have 0% Businessman, Because in data didn't show 1
# - Honk Kong have 0% House wife, Because in data didn't show 1
# - Honk Kong have 0% Other, Because in data didn't show 1

# %% [markdown]
# ## Oman Occupation Status

# %%
plt.figure(figsize=(5,5))
sns.barplot(data['Unemployed'],data[ 'Oman'])
plt.xlabel('Unemployed')
plt.ylabel( 'Oman')
plt.title(" 'Oman'vs Unemployment (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Working Professional'],data[ 'Oman'])
plt.xlabel('Working professionals')
plt.ylabel('Oman')
plt.title(" 'Oman'vs 'Working Professional' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Student'],data['Oman'])
plt.xlabel('Student')
plt.ylabel( 'Oman')
plt.title("'Oman' vs 'Student' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Businessman'],data[ 'Oman'])
plt.xlabel('Businessman')
plt.ylabel('Oman')
plt.title(" 'Oman' vs 'Businessman' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(5,5))
sns.barplot(data['Housewife'],data[ 'Oman'])
plt.xlabel('Housewife')
plt.ylabel('Oman')
plt.title(" 'Oman' vs 'Housewife' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Other'],data[ 'Oman'])
plt.xlabel('Other')
plt.ylabel('Oman')
plt.title("'Oman'vs 'Other' (Bar Plot)")
plt.legend()
plt.grid()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...

# %% [markdown]
# - Oman have 0.07% Unemployment(around 0.0007)(1)
# - Oman have 0% Working Professionals, Because in data didn't show 1
# - Oman have 0% Student, Because in data didn't show 1
# - Oman have 0% Businessman, Because in data didn't show 1
# - Oman have 0% House Wife, Because in data didn't show 1
# - Oman have 0% Other,Because in data didn't show 1

# %% [markdown]
# ## Russia Occupation Status

# %%
plt.figure(figsize=(5,5))
sns.barplot(data['Unemployed'],data[ 'Russia'])
plt.xlabel('Unemployed')
plt.ylabel( 'Russia')
plt.title(" 'Russia' vs Unemployment (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Working Professional'],data['Russia'])
plt.xlabel('Working professionals')
plt.ylabel('Russia')
plt.title(" 'Russia' vs 'Working Professional' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Student'],data['Russia'])
plt.xlabel('Student')
plt.ylabel('Russia')
plt.title("'Russia' vs 'Student' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Businessman'],data['Russia'])
plt.xlabel('Businessman')
plt.ylabel('Russia')
plt.title("'Russia' vs 'Businessman' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(5,5))
sns.barplot(data['Housewife'],data['Russia'])
plt.xlabel('Housewife')
plt.ylabel('Russia')
plt.title("'Russia' vs 'Housewife' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Other'],data[ 'Russia'])
plt.xlabel('Other')
plt.ylabel('Russia')
plt.title("'Russia' vs 'Other' (Bar Plot)")
plt.legend()
plt.grid()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...

# %% [markdown]
# - Russia have 0.07% Unemployment(around 0.0007)(1)
# - Russia have 0% Working Professionals, Because in data didn't show 1
# - Russia have 0% Students, Because in data didn't show 1
# - Russia have 0% Businessman, Because in data didn't show 1
# - Russia have 0% House Wife, Because in data didn't show 1
# - Russia have 0% Other, Because in data didn't show 1

# %% [markdown]
# ## Saudi Arabia Occupation Status

# %%
plt.figure(figsize=(5,5))
sns.barplot(data['Unemployed'],data[ 'Saudi Arabia'])
plt.xlabel('Unemployed')
plt.ylabel( 'Saudi Arabia')
plt.title(" 'Saudi Arabia' vs Unemployment (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Working Professional'],data['Saudi Arabia'])
plt.xlabel('Working professionals')
plt.ylabel('Saudi Arabia')
plt.title(" 'Saudi Arabia' vs 'Working Professional' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Student'],data['Saudi Arabia'])
plt.xlabel('Student')
plt.ylabel('Saudi Arabia')
plt.title("'Saudi Arabia' vs 'Student' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Businessman'],data['Saudi Arabia'])
plt.xlabel('Businessman')
plt.ylabel('Saudi Arabia')
plt.title("'Saudi Arabia' vs 'Businessman' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(5,5))
sns.barplot(data['Housewife'],data['Saudi Arabia'])
plt.xlabel('Housewife')
plt.ylabel('Saudi Arabia')
plt.title("'Saudi Arabia' vs 'Housewife' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Other'],data[ 'Saudi Arabia'])
plt.xlabel('Other')
plt.ylabel('Saudi Arabia')
plt.title("'Saudi Arabia' vs 'Other' (Bar Plot)")
plt.legend()
plt.grid()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...

# %% [markdown]
# - Saudi Arabia have 0.07% Unemployed(around 0.0007)(1)
# - Saudi Arabia have 0% Working Professionals, Because in data didn't show 1
# - Saudi Arabia have 0% Student, Because in data didn't show 1
# - Saudi Arabia have 0% Businessman, Because in data didn't show 1
# - Saudi Arabia have 0% House Wife, Because in data didn't show 1
# - Saudi Arabia have 0% Other, Because in data didn't show 1

# %% [markdown]
# ## Singapore Occupation status

# %%
plt.figure(figsize=(5,5))
sns.barplot(data['Unemployed'],data[ 'Singapore'])
plt.xlabel('Unemployed')
plt.ylabel('Singapore')
plt.title(" 'Singapore' vs Unemployment (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Working Professional'],data['Singapore'])
plt.xlabel('Working professionals')
plt.ylabel('Singapore')
plt.title(" 'Singapore' vs 'Working Professional' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Student'],data['Singapore'])
plt.xlabel('Student')
plt.ylabel('Singapore')
plt.title("'Singapore'vs 'Student' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Businessman'],data['Singapore'])
plt.xlabel('Businessman')
plt.ylabel('Singapore')
plt.title("'Singapore' vs 'Businessman' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(5,5))
sns.barplot(data['Housewife'],data['Singapore'])
plt.xlabel('Housewife')
plt.ylabel('Singapore')
plt.title("''Singapore' vs 'Housewife' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Other'],data[ 'Singapore'])
plt.xlabel('Other')
plt.ylabel('Singapore')
plt.title("'Singapore' vs 'Other' (Bar Plot)")
plt.legend()
plt.grid()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...

# %% [markdown]
# - Singapore have 0.07% Unemployed(around 0.0007)(1)
# - Singapore have 0% Working Professionals, Because in data didn't show 1
# - Singapore have 0% Student, Because in data didn't show 1
# - Singapore have 0% Businessman, Because in data didn't show 1
# - Singapore have 0% House Wife, Because in data didn't show 1
# - Singapore have 0% Other, Because in data didn't show 1

# %% [markdown]
# ## United Arab Emirates Occupation Status

# %%
plt.figure(figsize=(5,5))
sns.barplot(data['Unemployed'],data[ 'United Arab Emirates'])
plt.xlabel('Unemployed')
plt.ylabel('United Arab Emirates')
plt.title(" 'United Arab Emirates' vs Unemployment (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Working Professional'],data['United Arab Emirates'])
plt.xlabel('Working professionals')
plt.ylabel('United Arab Emirates')
plt.title(" 'United Arab Emirates' vs 'Working Professional' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Student'],data['United Arab Emirates'])
plt.xlabel('Student')
plt.ylabel('United Arab Emirates')
plt.title("'United Arab Emirates'vs 'Student' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Businessman'],data['United Arab Emirates'])
plt.xlabel('Businessman')
plt.ylabel('United Arab Emirates')
plt.title("'United Arab Emirates' vs 'Businessman' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(5,5))
sns.barplot(data['Housewife'],data['United Arab Emirates'])
plt.xlabel('Housewife')
plt.ylabel('Singapore')
plt.title("''United Arab Emirates' vs 'Housewife' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Other'],data[ 'United Arab Emirates'])
plt.xlabel('Other')
plt.ylabel('United Arab Emirates')
plt.title("'United Arab Emirates' vs 'Other' (Bar Plot)")
plt.legend()
plt.grid()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...

# %% [markdown]
# - United Arab Emirates have 0.2% Unemployed(0.002)(1)
# - United Arab Emirates have 0.013% Working Professionals(0.013)(1)
# - United Arab Emirates have 0% Student, Because in data didn't show 1
# - United Arab Emirates have 0% Businessman, Because in data didn't show 1
# - United Arab Emirates have 0% House Wife, Because in data didn't show 1
# - United Arab Emirates have 0% Other, Because in data didn't show 1

# %% [markdown]
# ##  United Kingdom Occupation Status

# %%
plt.figure(figsize=(5,5))
sns.barplot(data['Unemployed'],data[ 'United Kingdom'])
plt.xlabel('Unemployed')
plt.ylabel('United Kingdom')
plt.title(" 'United Kingdom' vs Unemployment (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Working Professional'],data['United Kingdom'])
plt.xlabel('Working professionals')
plt.ylabel('United Kingdom')
plt.title(" 'United Kingdom' vs 'Working Professional' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Student'],data['United Kingdom'])
plt.xlabel('Student')
plt.ylabel('United Kingdom')
plt.title("'United Kingdom'vs 'Student' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Businessman'],data['United Kingdom'])
plt.xlabel('Businessman')
plt.ylabel('United Kingdom')
plt.title("'United Kingdom' vs 'Businessman' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(5,5))
sns.barplot(data['Housewife'],data['United Kingdom'])
plt.xlabel('Housewife')
plt.ylabel('United Kingdom')
plt.title("''United Kingdom' vs 'Housewife' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Other'],data[ 'United Kingdom'])
plt.xlabel('Other')
plt.ylabel('United Kingdom')
plt.title("'United Kingdom' vs 'Other' (Bar Plot)")
plt.legend()
plt.grid()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...

# %% [markdown]
# - United Kingdom have 0.02% Unemployed( around 0.0021)(1)
# - United Kingdom have 0% Working Professionals, Because in data didn't show 1
# - United Kingdom have 0% Student, Because in data didn't show 1
# - United Kingdom have 0% Businessman, Because in data didn't show 1
# - United Kingdom have 0% House Wife, Because in data didn't show 1
# - United Kingdom have 0% Other, Because in data didn't show 1

# %% [markdown]
# ## United States Occupation Status

# %%
plt.figure(figsize=(5,5))
sns.barplot(data['Unemployed'],data[  'United States'])
plt.xlabel('Unemployed')
plt.ylabel( 'United States')
plt.title("  'United States' vs Unemployment (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Working Professional'],data[ 'United States'])
plt.xlabel('Working professionals')
plt.ylabel( 'United States')
plt.title(" 'United States' vs 'Working Professional' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Student'],data[ 'United States'])
plt.xlabel('Student')
plt.ylabel( 'United States')
plt.title(" 'United States' vs 'Student' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Businessman'],data[ 'United States'])
plt.xlabel('Businessman')
plt.ylabel( 'United States')
plt.title(" 'United States' vs 'Businessman' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(5,5))
sns.barplot(data['Housewife'],data[ 'United States'])
plt.xlabel('Housewife')
plt.ylabel( 'United States')
plt.title("' 'United States' vs 'Housewife' (Bar Plot)")
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(5,5))
sns.barplot(data['Other'],data[ 'United States'])
plt.xlabel('Other')
plt.ylabel( 'United States')
plt.title(" 'United States' vs 'Other' (Bar Plot)")
plt.legend()
plt.grid()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...

# %% [markdown]
# - United States have 0.23% Unemployed
# - United States have 0% Working Professional, Because in data didn't show 1
# - United State have 0% Student, Because in data didn't show 1
# - United States have 0% Businessman, Because in data didn't show 1
# - United States have 0% House Wife, Because in data didn't show 1
# - United States have 0% Other, Because in data didn't show 1
